# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('Autism-Adult-Data.csv')
df.columns = ['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score',
            'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score',
            'age', 'gender', 'ethnicity', 'jundice', 'austim', 'contry_of_res',
            'used_app_before', 'result', 'age_desc', 'relation', 'Class/ASD']

# %%
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         0         1         0         0         0
# 1         1         1         0         1         1         0         1
# 2         1         1         0         1         0         0         1
# 3         1         0         0         0         0         0         0
# 4         1         1         1         1         1         0         1
#
#    A8_Score  A9_Score  A10_Score  ... gender       ethnicity jundice austim  \
# 0         1         0          1  ...      m          Latino      no    yes
# 1         1         1          1  ...      m          Latino     yes    yes
# 2         1         0          1  ...      f  White-European      no    yes
# 3         1         0          0  ...      f               ?      no     no
# 4         1         1          1  ...      m          Others     yes     no
#
#      contry_of_res used_app_before result       age_desc relation Class/ASD
# 0           Brazil              no      5  '18 and more'     Self        NO
# 1            Spain              no      8  '18 and more'   Parent       YES
# 2  'United States'              no      6  '18 and more'     Self        NO
# 3            Egypt              no      2  '18 and more'        ?        NO
# 4  'United States'              no      9  '18 and more'     Self       YES
#
# [5 rows x 21 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         0         1         0         0         0
# 1           1         1         0         1         1         0         1
# 2           1         1         0         1         0         0         1
# 3           1         0         0         0         0         0         0
# 4           1         1         1         1         1         0         1
# ..        ...       ...       ...       ...       ...       ...       ...
# 698         0         1         0         1         1         0         1
# 699         1         0         0         0         0         0         0
# 700         1         0         1         1         1         0         1
# 701         1         0         0         1         1         0         1
# 702         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ... gender       ethnicity jundice austim  \
# 0           1         0          1  ...      m          Latino      no    yes
# 1           1         1          1  ...      m          Latino     yes    yes
# 2           1         0          1  ...      f  White-European      no    yes
# 3           1         0          0  ...      f               ?      no     no
# 4           1         1          1  ...      m          Others     yes     no
# ..        ...       ...        ...  ...    ...             ...     ...    ...
# 698         1         1          1  ...      f  White-European      no     no
# 699         1         0          1  ...      m        Hispanic      no     no
# 700         1         0          1  ...      f               ?      no     no
# 701         0         1          1  ...      m   'South Asian'      no     no
# 702         1         1          1  ...      f  White-European      no     no
#
#        contry_of_res used_app_before result       age_desc relation Class/ASD
# 0             Brazil              no      5  '18 and more'     Self        NO
# 1              Spain              no      8  '18 and more'   Parent       YES
# 2    'United States'              no      6  '18 and more'     Self        NO
# 3              Egypt              no      2  '18 and more'        ?        NO
# 4    'United States'              no      9  '18 and more'     Self       YES
# ..               ...             ...    ...            ...      ...       ...
# 698           Russia              no      7  '18 and more'     Self       YES
# 699           Mexico              no      3  '18 and more'   Parent        NO
# 700           Russia              no      7  '18 and more'        ?       YES
# 701         Pakistan              no      6  '18 and more'     Self        NO
# 702           Cyprus              no      8  '18 and more'     Self       YES
#
# [698 rows x 21 columns]
